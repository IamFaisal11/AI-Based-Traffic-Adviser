# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.1/871.1 kB 27.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n-obb.yaml")

# %%
# Train the model on the DOTAv2 dataset
results = model.train(data="DOTAv1.yaml", epochs=40, imgsz=416, batch=8)
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
result=model("/content/datasets/DOTAv1/images/train/P0000.jpg")
# Out:
# image 1/1 /content/datasets/DOTAv1/images/train/P0000.jpg: 320x256 45.8ms
# Speed: 1.9ms preprocess, 45.8ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 256)

# %%
result[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: 'plane', 1: 'ship', 2: 'storage tank', 3: 'baseball diamond', 4: 'tennis court', 5: 'basketball court', 6: 'ground track field', 7: 'harbor', 8: 'bridge', 9: 'large vehicle', 10: 'small vehicle', 11: 'helicopter', 12: 'roundabout', 13: 'soccer ball field', 14: 'swimming pool'}
# obb: ultralytics.engine.results.OBB object
# orig_img: array([[[3, 1, 0],
#         [3, 1, 0],
#         [3, 1, 0],
#         ...,
#         [3, 1, 1],
#         [3, 1, 1],
#         [3, 1, 1]],
#
#        [[3, 1, 0],
#         [3, 1, 0],
#         [3, 1, 0],
#         ...,
#         [3, 1, 1],
#         [1, 1, 1],
#         [3, 1, 1]],
#
#        [[3, 1, 0],
#         [3, 1, 0],
#         [3, 1, 0],
#         ...,
#         [1, 0, 2],
#         [0, 1, 2],
#         [1, 0, 2]],
#
#        ...,
#
#        [[1, 1, 1],
#         [1, 1, 1],
#         [1, 1, 1],
#         ...,
# ...

# %%
model.save("/content/model_saved.pt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-16bfb82d0289> in <cell line: 1>()
# ----> 1 model.save("/content/model_saved.pt")
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in save(self, filename, use_dill)
#     419             "docs": "https://docs.ultralytics.com",
#     420         }
# --> 421         torch.save({**self.ckpt, **updates}, filename, use_dill=use_dill)
#     422
#     423     def info(self, detailed: bool = False, verbose: bool = True):
#
# TypeError: 'NoneType' object is not a mapping

# %%
model1=YOLO("/content/runs/obb/train3/weights/best.pt")

# %%
result=model1("/content/download.jpeg")
# Out:
# image 1/1 /content/download.jpeg: 320x192 (no detections), 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 192)

# %%
result[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: 'plane', 1: 'ship', 2: 'storage tank', 3: 'baseball diamond', 4: 'tennis court', 5: 'basketball court', 6: 'ground track field', 7: 'harbor', 8: 'bridge', 9: 'large vehicle', 10: 'small vehicle', 11: 'helicopter', 12: 'roundabout', 13: 'soccer ball field', 14: 'swimming pool'}
# obb: ultralytics.engine.results.OBB object
# orig_img: array([[[101,  74,  70],
#         [115,  90,  86],
#         [126, 101,  97],
#         ...,
#         [166, 135, 102],
#         [113,  82,  49],
#         [ 88,  58,  23]],
#
#        [[115,  88,  84],
#         [124,  99,  95],
#         [127, 105, 100],
#         ...,
#         [100,  69,  38],
#         [ 85,  54,  21],
#         [ 90,  59,  26]],
#
#        [[106,  81,  77],
#         [111,  86,  82],
#         [112,  90,  84],
#         ...,
#         [ 83,  53,  24],
#         [ 77,  48,  17],
#         [ 74,  45,  14]],
#
# ...
